# %% [markdown]
# <a href="https://colab.research.google.com/github/amirahhoss/DSproject/blob/main/Stock_Price_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction
# This code reads in Tesla's stock prices during the period of time Musk's tweets were recorded, and visualizes the dataset

# %% [markdown]
# # Import yfinance and collecting stock data
# Collect stock prices of relevant dates, then graph them

# %%
import yfinance as yf
tesla_stock=yf.download('TSLA','2022-07-05','2023-06-03')
tesla_stock.Close.plot(figsize=(15,8),  title='Tesla Stock Price',ylabel='Price')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Exploring structure of tesla stock dataframe

# %%
tesla_stock.head()
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2022-07-05  233.066666  233.146667  216.166672  223.000000   84581100
# 2022-07-06  231.733337  234.563339  227.186661  230.779999   71853600
# 2022-07-07  244.543335  245.363327  232.210007  233.919998   81930600
# 2022-07-08  250.763336  254.979996  241.160004  242.333328  101854200
# 2022-07-11  234.343338  253.063339  233.626663  252.103333   99241200
#
# Price        datetime
# Ticker
# Date
# 2022-07-05 2022-07-05
# 2022-07-06 2022-07-06
# 2022-07-07 2022-07-07
# 2022-07-08 2022-07-08
# 2022-07-11 2022-07-11
